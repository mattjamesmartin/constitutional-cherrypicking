# %% [markdown]
# # Pubcon Installer
#
# Install the the following resources:
#
# - Universal Sentence Encoder (version 3)
# - Source data
# - Pre-compiled model files

# %% [markdown]
# ## Run installation

# %%
print("Installing the gdown package…")
# !pip install --upgrade --no-cache-dir gdown
print()

# Data
print("Downloading data…")
# !gdown 'https://drive.google.com/uc?id=1jdo66rQkj47ECDCTwy9FIkZ1GqejwdYn' -O data.zip
print("Unzipping data.zip…")
# !unzip -o 'data.zip'
print("Cleaning up…")
# !rm 'data.zip'
# !rm -rf '__MACOSX'
print()

# CCP model
print("Downloading CCP model…")
# !gdown 'https://drive.google.com/uc?id=1hAWUvnsBCwj689NmEOg-sp8iyIfk6oZ0' -O model.zip
print("Unzipping model.zip…")
# !unzip -o 'model.zip'
print("Cleaning up…")
# !rm 'model.zip'
# !rm -rf '__MACOSX'
print()

# spaCy model 3.7.0
print('Downloading spaCy es_core_news_lg-3.7.0…')
# !gdown 'https://drive.google.com/uc?id=1Ke92wEhu2qJSsNwr-O1o_b9GjCmUIDRc' -O es_core_news_lg-3.7.0.zip
print('Unzipping…')
# !unzip './es_core_news_lg-3.7.0.zip'
print('Clearing up…')
# !rm 'es_core_news_lg-3.7.0.zip'
# !rm -r  './__MACOSX'
print()

# USE model
print("Downloading USE model…")
# !gdown 'https://drive.google.com/uc?id=1-wIXc9Y2tt9tklxTenk7ilu5ykQH5tG3' -O use_ml_3.zip
print("Unzipping use_ml_3.zip…")
# !unzip -o 'use_ml_3.zip'
print("Cleaning up…")
# !rm 'use_ml_3.zip'
# !rm -rf '__MACOSX'
print()

print("All downloads complete. You're good to go!")
# Out:
# Installing the gdown package…
# ...
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
#
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1jdo66rQkj47ECDCTwy9FIkZ1GqejwdYn
# To: /Users/mattmartin/Downloads/pubcon-main/data.zip
# 100%|██████████████████████████████████████| 10.8M/10.8M [00:00<00:00, 24.9MB/s]
# Unzipping data.zip…
# Archive:  data.zip
#    creating: data/
#   inflating: __MACOSX/._data
#   inflating: data/.DS_Store
#   inflating: __MACOSX/data/._.DS_Store
#    creating: data/Cuba/
#   inflating: __MACOSX/data/._Cuba
# ...
